# %% [markdown]
# # Pruebas de API:
# Aquí estaba probando descargar los datos para el pipeline y ver la API de spotify

# %%
import requests
import simplejson as json

# Intento 1: Spotify
url_spotify = "https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6"
headers = {"Authorization": "Bearer BQD1...AQUI_IBA_MI_TOKEN_QUE_YA_CADUCO"}
res = requests.get(url_spotify, headers=headers)
print("Spotify Response:", res.status_code)
print(res.json())

# %% [markdown]
# **Error 401!** Me pedía renovar el token a cada rato con OAuth porque caducan súper rápido. Muy complicado para el tiempo que tengo en el proyecto.
#
# Probando alternativa: **Deezer API** (Pública, no pide autenticación)

# %%
# Intento 2: Deezer
url_deezer = "https://api.deezer.com/artist/1424954"
res_dz = requests.get(url_deezer)
print("Deezer Response:", res_dz.status_code)
print(res_dz.json()['name'], "-", res_dz.json()['nb_fan'], "fans")

# Funciona a la primera, decidí usar esta para el pipeline en src/extract.py :)
